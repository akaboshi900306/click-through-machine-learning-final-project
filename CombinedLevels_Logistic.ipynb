# %% [markdown]
# # Import Data

# %%
import pandas as pd

# plot
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import random
import numpy as np
import seaborn as sns

pd.set_option('display.max_columns', 25)

# %%
# read data
train = pd.read_csv(r'C:\Users\Amy Sung\Desktop\1222 ML Project\Project Data\ProjectTrainingData.csv')
test = pd.read_csv(r'C:\Users\Amy Sung\Desktop\1222 ML Project\Project Data\ProjectTestData.csv')

# %% [markdown]
# # Look at Overall train and test data

# %%
print(train.shape)
print(test.shape)
# Out:
# (31991090, 24)
# (13015341, 23)

# %%
train.head()
# Out:
#              id  click      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain app_category device_id device_ip  \
# 0      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a  ddd2926e
# 1      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a  96809ac8
# 2      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a  b3cf8def
# 3      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a  e8275b8f
# 4      0569f928  ecad2386   7801e8d9     07d7df22  a99f214a  9644d0bf
#
#   device_model  device_type  device_conn_type    C14  C15  C16   C17  C18  \
# ...

# %%
train.describe()
# Out:
#                  id         click          hour            C1    banner_pos  \
# count  3.199109e+07  3.199109e+07  3.199109e+07  3.199109e+07  3.199109e+07
# mean   9.222850e+18  1.698903e-01  1.410251e+07  1.004971e+03  2.939784e-01
# std    5.325227e+18  3.755364e-01  2.675669e+02  1.115785e+00  5.104750e-01
# min    5.211594e+11  0.000000e+00  1.410210e+07  1.001000e+03  0.000000e+00
# 25%    4.611571e+18  0.000000e+00  1.410222e+07  1.005000e+03  0.000000e+00
# 50%    9.223074e+18  0.000000e+00  1.410251e+07  1.005000e+03  0.000000e+00
# 75%    1.383506e+19  0.000000e+00  1.410280e+07  1.005000e+03  1.000000e+00
# max    1.844674e+19  1.000000e+00  1.410292e+07  1.012000e+03  7.000000e+00
#
#         device_type  device_conn_type           C14           C15  \
# count  3.199109e+07      3.199109e+07  3.199109e+07  3.199109e+07
# mean   1.018130e+00      3.284549e-01  1.858369e+04  3.188418e+02
# std    5.406309e-01      8.561166e-01  4.977359e+03  2.156021e+01
# ...

# %%
test.head()
# Out:
#                      id      hour    C1  banner_pos   site_id site_domain  \
# 0   3295858251275419735  14102809  1005           1  85f751fd    c4e18dd6
# 1  12281702837842634283  14103120  1007           0  85f751fd    c4e18dd6
# 2   4638380339534007785  14103109  1005           0  4e7614cf    c1aa3c04
# 3  17039804736879076347  14103101  1002           0  48c42b43    de0f0f82
# 4   5753064066292192109  14103119  1005           1  e151e245    7e091613
#
#   site_category    app_id app_domain app_category device_id device_ip  \
# 0      50e219e0  1dc72b4d   2347f47a     0f2161f8  cd915ca3  834cff24
# 1      50e219e0  8311368f   1dc9b529     0f2161f8  ec0aff16  6f6d6456
# 2      f028772b  ecad2386   7801e8d9     07d7df22  a99f214a  bd807c39
# 3      50e219e0  ecad2386   7801e8d9     07d7df22  dfb9b781  5ce9f91d
# 4      f028772b  ecad2386   7801e8d9     07d7df22  a99f214a  0da60c14
#
#   device_model  device_type  device_conn_type    C14  C15  C16   C17  C18  \
# ...

# %%
test.describe()
# Out:
#                  id          hour            C1    banner_pos   device_type  \
# count  1.301534e+07  1.301534e+07  1.301534e+07  1.301534e+07  1.301534e+07
# mean   9.223718e+18  1.410288e+07  1.004967e+03  2.462825e-01  1.006340e+00
# std    5.326120e+18  3.051849e+02  9.829727e-01  4.845275e-01  4.582598e-01
# min    1.398959e+12  1.410210e+07  1.001000e+03  0.000000e+00  0.000000e+00
# 25%    4.610782e+18  1.410281e+07  1.005000e+03  0.000000e+00  1.000000e+00
# 50%    9.225027e+18  1.410301e+07  1.005000e+03  0.000000e+00  1.000000e+00
# 75%    1.383742e+19  1.410311e+07  1.005000e+03  0.000000e+00  1.000000e+00
# max    1.844674e+19  1.410312e+07  1.012000e+03  7.000000e+00  5.000000e+00
#
#        device_conn_type           C14           C15           C16  \
# count      1.301534e+07  1.301534e+07  1.301534e+07  1.301534e+07
# mean       3.536481e-01  2.048630e+04  3.194561e+02  5.976233e+01
# std        8.665138e-01  4.530735e+03  2.350921e+01  4.634691e+01
# ...

# %%
train.click.value_counts()
# Out:
# 0    26556113
# 1     5434977
# Name: click, dtype: int64

# %%
# Train data Oct21@12am - Oct29@11pm
print(min(train.hour))
print(max(train.hour))
# Out:
# 14102100
# 14102923

# %%
# Test data Oct21@12am - Oct21@11pm
min(test.hour)
print(max(test.hour))
# Out:
# 14102100
# 14103123

# %%
# Change train variables to categorical variables
for i in range(2, 23):
        train.iloc[:, i] = train.iloc[:, i].astype('category')

# %%
# Look at number of categories in each variable
for i in range(3, 24):
        print(i, len(train.iloc[:, i].unique()) )
# Out:
# 3 7
# 4 7
# 5 4581
# 6 7341
# 7 26
# 8 8088
# 9 526
# 10 36
# 11 2296165
# 12 5762925
# 13 8058
# 14 5
# 15 4
# 16 2465
# 17 8
# 18 9
# 19 407
# 20 4
# 21 66
# 22 171
# 23 55

# %%
# Get unique categories within each variable 
for i in range(3, 24):
        print(i, train.iloc[:, i].value_counts())
# Out:
# 3 1005    29303261
# 1002     1797703
# 1010      756708
# 1012       91153
# 1007       29113
# 1001        8121
# 1008        5031
# Name: C1, dtype: int64
# 4 0    22851592
# 1     9080926
# 7       35522
# 2       10220
# 4        6130
# 5        5025
# 3        1675
# Name: banner_pos, dtype: int64
# 5 85f751fd    11170690
# 1fbe01fe     5216249
# e151e245     2095395
# d9750ee7      786829
# 5b08c53b      719069
# 856e6d3f      640406
# 5b4d2eda      609383
# a7853007      407182
# b7e9786d      296046
# 5bcf81a2      292307
# 5ee41ff2      285591
# 6399eda6      275991
# 6256f5b4      254435
# 17caea14      224851
# 83a0ad1a      218829
# 57ef2c87      218449
# 0a742914      218291
# 57fe1b20      214034
# e8f79e60      208776
# e4d8dd7b      204413
# d6137915      183807
# 12fb4121      167312
# 6c5b482c      154980
# 9a977531      148007
# 5114c672      146012
# e5c60a05      145582
# 93eaba74      144514
# bb4524e7      138102
# e3c09f3a      133061
# ce3307ec      122689
# ...

# %%
# Change test variables to categorical variables
for i in range(2, 23):
        test.iloc[:, i] = test.iloc[:, i].astype('category')

# %%
# C14, C17, C19, C21 fewer categories than train data
for i in range(2, 23):     
        print(i, len(test.iloc[:, i].unique()))
# Out:
# 2 7
# 3 7
# 4 3951
# 5 5268
# 6 25
# 7 6629
# 8 395
# 9 31
# 10 1020427
# 11 3215738
# 12 6990
# 13 5
# 14 4
# 15 2773
# 16 8
# 17 9
# 18 472
# 19 4
# 20 68
# 21 170
# 22 62

# %%
# Get unique categories within each variable
for i in range(2, 23):
        print(i, test.iloc[:, i].value_counts())
# Out:
# 2 1005    12154064
# 1002      590534
# 1010      214009
# 1012       36754
# 1007       15891
# 1001        3332
# 1008         757
# Name: C1, dtype: int64
# 3 0    9911648
# 1    3079550
# 7      13637
# 2       4363
# 3       3609
# 4       1781
# 5        753
# Name: banner_pos, dtype: int64
# 4 85f751fd    5144751
# 1fbe01fe    1699763
# 17d1b03f     813053
# e151e245     811224
# 5b08c53b     290072
# 5b4d2eda     250950
# d9750ee7     237229
# 856e6d3f     157682
# 57ef2c87     130195
# b7e9786d     100261
# 5ee41ff2      98429
# 6399eda6      88550
# e4d8dd7b      80518
# 6256f5b4      78588
# d6137915      75716
# 83a0ad1a      73348
# 17caea14      67736
# 57fe1b20      65950
# 4e7614cf      65610
# e8f79e60      64305
# 0a742914      63293
# 93eaba74      62229
# a7853007      54635
# 5bcf81a2      53213
# 6c5b482c      50849
# bb4524e7      45621
# 12fb4121      45087
# e5c60a05      44480
# e3c09f3a      39312
# 4bf5bbe2      38399
#              ...
# ...

# %% [markdown]
# # Sample Train data

# %%
# read "train"data
train021 = pd.read_csv(r'C:\Users\Amy Sung\Desktop\1222 ML Project\Project Data\AmyTrain\Train-021.csv', header = None)
train021 = pd.DataFrame(train021.values, columns = ['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category', 'device_id', 
                                  'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14','C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'])

# %%
# read "validation" data
train025 = pd.read_csv(r'C:\Users\Amy Sung\Desktop\1222 ML Project\Project Data\AmyTrain\Train-025.csv', header = None)
train025 = pd.DataFrame(train021.values, columns = ['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category', 'device_id', 
                                  'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14','C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'])

# %%
print(train021.shape)
print(train025.shape)
# Out:
# (1000000, 24)
# (1000000, 24)

# %%
# Train head
train021.head()
# Out:
#                      id click      hour    C1 banner_pos   site_id  \
# 0  12785638241520022220     0  14102607  1005          1  e151e245
# 1  11522005476236429973     0  14102514  1005          0  85f751fd
# 2  14583678471890575931     0  14102816  1005          0  85f751fd
# 3   2711603864343840520     0  14102515  1005          0  7294ea0f
# 4   1985350963527076202     0  14102313  1005          0  85f751fd
#
#   site_domain site_category    app_id app_domain app_category device_id  \
# 0    7e091613      f028772b  ecad2386   7801e8d9     07d7df22  a99f214a
# 1    c4e18dd6      50e219e0  ce183bbd   ae637522     cef3e649  a99f214a
# 2    c4e18dd6      50e219e0  73206397   2347f47a     8ded1f7a  76282743
# 3    863fa89d      3e814130  ecad2386   7801e8d9     07d7df22  a99f214a
# 4    c4e18dd6      50e219e0  d36838b1   0e8616ad     0f2161f8  a99f214a
#
#   device_ip device_model device_type device_conn_type    C14  C15 C16   C17  \
# ...

# %%
# Train descriptive statistics
train021.describe()
# Out:
#                           id    click      hour       C1  banner_pos  \
# count                1000000  1000000   1000000  1000000     1000000
# unique               1000000        2       216        7           7
# top     16256483781444108280        0  14102209     1005           0
# freq                       1   830493     12545   915842      713802
#
#          site_id site_domain site_category    app_id app_domain app_category  \
# count    1000000     1000000       1000000   1000000    1000000      1000000
# unique      2655        2868            21      3091        196           27
# top     85f751fd    c4e18dd6      50e219e0  ecad2386   7801e8d9     07d7df22
# freq      348763      362332        397823    651237     687528       659958
#
#        device_id device_ip device_model  device_type  device_conn_type  \
# count    1000000   1000000      1000000      1000000           1000000
# unique    152178    547253         5156            4                 4
# ...

# %%
# Val Head
train025.head()
# Out:
#                      id click      hour    C1 banner_pos   site_id  \
# 0  12785638241520022220     0  14102607  1005          1  e151e245
# 1  11522005476236429973     0  14102514  1005          0  85f751fd
# 2  14583678471890575931     0  14102816  1005          0  85f751fd
# 3   2711603864343840520     0  14102515  1005          0  7294ea0f
# 4   1985350963527076202     0  14102313  1005          0  85f751fd
#
#   site_domain site_category    app_id app_domain app_category device_id  \
# 0    7e091613      f028772b  ecad2386   7801e8d9     07d7df22  a99f214a
# 1    c4e18dd6      50e219e0  ce183bbd   ae637522     cef3e649  a99f214a
# 2    c4e18dd6      50e219e0  73206397   2347f47a     8ded1f7a  76282743
# 3    863fa89d      3e814130  ecad2386   7801e8d9     07d7df22  a99f214a
# 4    c4e18dd6      50e219e0  d36838b1   0e8616ad     0f2161f8  a99f214a
#
#   device_ip device_model device_type device_conn_type    C14  C15 C16   C17  \
# ...

# %%
# Val descriptive statistics
train025.describe()
# Out:
#                           id    click      hour       C1  banner_pos  \
# count                1000000  1000000   1000000  1000000     1000000
# unique               1000000        2       216        7           7
# top     16256483781444108280        0  14102209     1005           0
# freq                       1   830493     12545   915842      713802
#
#          site_id site_domain site_category    app_id app_domain app_category  \
# count    1000000     1000000       1000000   1000000    1000000      1000000
# unique      2655        2868            21      3091        196           27
# top     85f751fd    c4e18dd6      50e219e0  ecad2386   7801e8d9     07d7df22
# freq      348763      362332        397823    651237     687528       659958
#
#        device_id device_ip device_model  device_type  device_conn_type  \
# count    1000000   1000000      1000000      1000000           1000000
# unique    152178    547253         5156            4                 4
# ...

# %%
# Date range from Oct21@12am - Oct29@23pm - Train
print(min(train021.hour))
print(max(train021.hour))
# Out:
# 14102100
# 14102923

# %%
# Date range from Oct21@12am - Oct29@23pm - Val
print(min(train025.hour))
print(max(train025.hour))
# Out:
# 14102100
# 14102923

# %%
# get date of sample - Train
train021['hour'] = train021['hour'].astype('int') 
train021['date'] = round((train021.hour - 14100000)/100).astype('int')

# get hour of sample - Train
train021.hour = train021.hour - 14100000 - train021.date * 100


# get date of sample - Val
train025['hour'] = train025['hour'].astype('int') 
train025['date'] = round((train025.hour - 14100000)/100).astype('int')

# get hour of sample - Val
train025.hour = train025.hour - 14100000 - train025.date * 100

# %%
# Delete ID since all unique values
train021 = train021.iloc[:, 1:] # delete id
print(train021.columns)

train025 = train025.iloc[:, 1:] # delete id
print(train025.columns)
# Out:
# Index(['click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'date'],
#       dtype='object')
# Index(['click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'date'],
#       dtype='object')

# %%
#  Distribution of click - Train
count = train021["click"].value_counts()
count.plot(kind = "bar", title = "count")

# %%
# Percentage of click and non-click - Train
count_click = len(train021[train021['click']==1])
print("click", count_click)
count_noclick = len(train021[train021['click']==0])
print("noclick", count_noclick)
pct_click = count_click/(count_click+count_noclick)
print("percentage of click", pct_click*100)
pct_noclick = count_noclick/(count_click+count_noclick)
print("percentage of no click", pct_noclick*100)
# Out:
# click 169507
# noclick 830493
# percentage of click 16.950699999999998
# percentage of no click 83.0493

# %%
# Check how many categories within each variable - Train <10th - device id, 11th - device ip>
for i in range(1, 24):
        print(i, len(train021.iloc[:, i].unique()) )
# Out:
# 1 24
# 2 7
# 3 7
# 4 2655
# 5 2868
# 6 21
# 7 3091
# 8 196
# 9 27
# 10 152178
# 11 547253
# 12 5156
# 13 4
# 14 4
# 15 2110
# 16 8
# 17 9
# 18 398
# 19 4
# 20 65
# 21 165
# 22 55
# 23 9

# %%
# Get unique categories count within each variable - Train <site id, site domain, app id, app domain, device model, C14>
for i in range(1, 24):
        print(i, train021.iloc[:, i].value_counts())
# Out:
# 1 13    59180
# 9     57703
# 12    54180
# 10    53679
# 14    53616
# 8     53401
# 17    51246
# 15    51173
# 16    50759
# 11    50288
# 5     47907
# 7     46835
# 18    43850
# 6     43507
# 4     43341
# 3     35330
# 19    32822
# 2     30623
# 20    28143
# 1     24689
# 21    24470
# 22    22146
# 0     20954
# 23    20158
# Name: hour, dtype: int64
# 2 1005    915842
# 1002     56440
# 1010     23530
# 1012      2846
# 1007       936
# 1001       250
# 1008       156
# Name: C1, dtype: int64
# 3 0    713802
# 1    284349
# 7      1121
# 2       331
# 4       176
# 5       156
# 3        65
# Name: banner_pos, dtype: int64
# 4 85f751fd    348763
# 1fbe01fe    162756
# e151e245     65322
# d9750ee7     24626
# 5b08c53b     22708
# 856e6d3f     20115
# 5b4d2eda     18930
# a7853007     12726
# b7e9786d      9251
# 5bcf81a2      9063
# 5ee41ff2      8930
# 6399eda6      8690
# 6256f5b4      7892
# 17caea14      7120
# 57ef2c87      7029
# 83a0ad1a      7004
# ...

# %%
# Drop device id and device ip since too many categories

train021.drop(['device_id', 'device_ip'], axis = 1, inplace = True) 
train025.drop(['device_id', 'device_ip'], axis = 1, inplace = True)

# %%
train021.columns
# Out:
# Index(['click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_model',
#        'device_type', 'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18',
#        'C19', 'C20', 'C21', 'date'],
#       dtype='object')

# %% [markdown]
# ## Combine Category

# %%
train021.dtypes
# Out:
# click               object
# hour                 int32
# C1                  object
# banner_pos          object
# site_id             object
# site_domain         object
# site_category       object
# app_id              object
# app_domain          object
# app_category        object
# device_model        object
# device_type         object
# device_conn_type    object
# C14                 object
# C15                 object
# C16                 object
# C17                 object
# C18                 object
# C19                 object
# C20                 object
# C21                 object
# date                 int32
# dtype: object

# %%
# Change value type to string - Train
for i in range(1, 22):
        train021.iloc[:, i] = train021.iloc[:, i].astype('str')

# %%
# Change value type to string - Val
for i in range(1, 22):
        train025.iloc[:, i] = train021.iloc[:, i].astype('str')

# %%
# Combine levels for selected variables - Train
for i in np.r_[4,5,7,8,10,13,16,19]:
    count =pd.DataFrame(train021.iloc[:, i].value_counts())
    count['freq'] = count[count.columns[0]].cumsum()
    category = count.index.values[:(count[count.freq <= 800000].shape[0]+1)]
    allcategory =train021.iloc[:,i].unique()
    diff = np.setdiff1d(allcategory, category)
    train021.iloc[: ,i] = train021.iloc[:,i].replace(diff,"1111111")

# %%
###for i in range(1, 22):
###        train021.iloc[:, i] = train021.iloc[:, i].astype('category')

# %%
###for i in range(1, 22):
###        train025.iloc[:, i] = train025.iloc[:, i].astype('category')

# %%
# Combine levels for selected variables - Validation
for i in np.r_[4,5,7,8,10,13,16,19]:
    category = train021.iloc[:, i].unique()
    allcategory =train025.iloc[:,i].unique()
    diff = np.setdiff1d(allcategory, category)
    train025.iloc[: ,i] = train025.iloc[:,i].replace(diff, "1111111")

# %%
for i in range(1, 22):
        print(i, len(train025.iloc[:, i].unique()) )
# Out:
# 1 24
# 2 7
# 3 7
# 4 28
# 5 20
# 6 21
# 7 11
# 8 3
# 9 27
# 10 286
# 11 4
# 12 4
# 13 1
# 14 8
# 15 9
# 16 1
# 17 4
# 18 65
# 19 1
# 20 55
# 21 9

# %%
for i in range(1, 22):
        print(i, len(train021.iloc[:, i].unique()) )
# Out:
# 1 24
# 2 7
# 3 7
# 4 28
# 5 20
# 6 21
# 7 11
# 8 3
# 9 27
# 10 286
# 11 4
# 12 4
# 13 194
# 14 8
# 15 9
# 16 72
# 17 4
# 18 65
# 19 11
# 20 55
# 21 9

# %%
# Click distribution for combined levels
train021.groupby(["device_model","click"]).size()
# Out:
# device_model  click
# 00b1f3a7      0        1842
#               1         499
# 0153a639      0        1094
#               1         271
# 021b641d      0         583
#               1         110
# 034b811d      0         647
#               1         159
# 03683bd4      0        3041
#               1         409
# 04258293      0        1115
#               1         195
# 04f5b394      0        3154
#               1         756
# 051263ee      0         680
#               1          77
# 054c8edf      0        1535
#               1          19
# 05b9fa1b      0         469
#               1          64
# 05e70df4      0        2797
#               1         762
# 0671f8e1      0         504
#               1          84
# 06fbfd42      0         436
#               1          89
# 072c9f1e      0         585
#               1         133
# 08ac11ab      0        2502
#               1         620
#                        ...
# f07e20f8      0        8276
# ...

# %%
#Change to category and same levels
for i in range(1,22):
    categories = np.union1d(train021.iloc[:,i], train025.iloc[:,i])
    train021.iloc[:,i] = pd.Categorical(train021.iloc[:,i], categories=categories)
    train025.iloc[:,i] = pd.Categorical(train025.iloc[:,i], categories=categories)

# %% [markdown]
# ## Split X and Y

# %%
xtrain = train021.iloc[ : , 1: ]
ytrain= train021.iloc[ :, 0]

xval = train025.iloc[:, 1: ]
yval = train025.iloc[:, 0]

# %% [markdown]
# ## Logistic - Ordinal Value

# %%
# Recode value into ordinal values
from sklearn.preprocessing import LabelEncoder

xtrain_label = xtrain.values
xval_label = xval.values

for i in range(0,21):
    le = LabelEncoder()
    le.fit(xtrain.iloc[:, i])
    xtrain_label[:, i] = le.transform(xtrain_label[:, i])
    xval_label[:, i] = le.transform(xval_label[:, i])

# %%
# Fit Logistic Regression and Calculate Log Loss
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
l = LogisticRegression()

ytrain=ytrain.astype('int')
yval=yval.astype('int')

l.fit(xtrain_label, ytrain)
ypred = l.predict(xval_label)
ypred_prob = l.predict_proba(xval_label)
print(log_loss(yval, ypred_prob))
# Out:
# 0.4375593325077466

# %%
# Performance Measurement
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from sklearn.metrics import confusion_matrix

accuracy = sum(ypred == yval)/len(yval)
error = 1 - accuracy
print("The predictive accuracy is: ", round(accuracy, 2))
print("The classification error is: ", round(error, 2))
print(classification_report(yval, ypred))

# Confusion matrix

cnf_matrix = pd.DataFrame(confusion_matrix(yval, ypred))
print("The Confusion matrix: \n", cnf_matrix)
# Out:
# The predictive accuracy is:  0.83
# The classification error is:  0.17
#              precision    recall  f1-score   support
#
#           0       0.83      1.00      0.91    830493
#           1       0.43      0.00      0.00    169507
#
# avg / total       0.76      0.83      0.75   1000000
#
# The Confusion matrix:
#          0    1
# 0  830209  284
# 1  169292  215

# %% [markdown]
# # Logistic - One Hot Encoder

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(handle_unknown='ignore')
ohe.fit(xtrain_label)
xtrain_ohe = ohe.transform(xtrain_label)
xval_ohe = ohe.transform(xval_label)
xtrain_ohe
# Out:
# <1000000x16883 sparse matrix of type '<class 'numpy.float64'>'
# 	with 21000000 stored elements in Compressed Sparse Row format>

# %%
# Fit Logistic Regression and Calculate Log Loss
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
l = LogisticRegression()

ytrain=ytrain.astype('int')
yval=yval.astype('int')

l.fit(xtrain_ohe, ytrain)
ypred = l.predict(xval_ohe)
ypred_prob = l.predict_proba(xval_ohe)
print(log_loss(yval, ypred_prob))
# Out:
# 0.39056768331469105

# %%
# Performance Measurement
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from sklearn.metrics import confusion_matrix

accuracy = sum(ypred == yval)/len(yval)
error = 1 - accuracy
print("The predictive accuracy is: ", round(accuracy, 2))
print("The classification error is: ", round(error, 2))
print(classification_report(yval, ypred))

# Confusion matrix

cnf_matrix = pd.DataFrame(confusion_matrix(yval, ypred))
print("The Confusion matrix: \n", cnf_matrix)
# Out:
# The predictive accuracy is:  0.84
# The classification error is:  0.16
#              precision    recall  f1-score   support
#
#           0       0.84      0.99      0.91    830493
#           1       0.62      0.09      0.16    169507
#
# avg / total       0.80      0.84      0.78   1000000
#
# The Confusion matrix:
#          0      1
# 0  821034   9459
# 1  154284  15223

# %% [markdown]
# ## Logistic - Dummy

# %%
### Change to category type for dummy coding - Train
for i in range(0, 21):
        xtrain.iloc[:, i] = xtrain.iloc[:, i].astype('category')
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Create dummy variables - Train
xtrain_dummy = pd.get_dummies(xtrain, prefix=['hour', 'C1', 'banner_pos', 'site_id', 'site_domain','site_category', 'app_id', 'app_domain', 
                                              'app_category', 'device_model', 'device_type', 'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18', 
                                              'C19', 'C20', 'C21', 'date'], drop_first = True)

# %%
### Change to category type for dummy coding - Val
for i in range(0, 21):
        xval.iloc[:, i] = xval.iloc[:, i].astype('category')

# %%
# Create dummy variables - Val
xval_dummy = pd.get_dummies(xval, prefix=['hour', 'C1', 'banner_pos', 'site_id', 'site_domain','site_category', 'app_id', 'app_domain', 
                                              'app_category', 'device_model', 'device_type', 'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18', 
                                              'C19', 'C20', 'C21', 'date'], drop_first = True)

# %%
xtrain_dummy.shape
# Out:
# (1000000, 848)

# %%
ytrain = ytrain.astype('category') 
yval = yval.astype('category')

# %%
# Fit Logistic Regression and Calculate Log Loss
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
l = LogisticRegression()

l.fit(xtrain_dummy,ytrain)
ypred = l.predict(xval_dummy)
ypred_prob = l.predict_proba(xval_dummy)
print(log_loss(yval, ypred_prob))
# Out:
# 0.4089309153490821

# %%
# Performance Measurement
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from sklearn.metrics import confusion_matrix

accuracy = sum(ypred == yval)/len(yval)
error = 1 - accuracy
print("The predictive accuracy is: ", round(accuracy, 2))
print("The classification error is: ", round(error, 2))
print(classification_report(yval, ypred))

# Confusion matrix

cnf_matrix = pd.DataFrame(confusion_matrix(yval, ypred))
print("The Confusion matrix: \n", cnf_matrix)
# Out:
# The predictive accuracy is:  0.83
# The classification error is:  0.17
#              precision    recall  f1-score   support
#
#           0       0.84      0.99      0.91    830493
#           1       0.55      0.05      0.09    169507
#
# avg / total       0.79      0.83      0.77   1000000
#
# The Confusion matrix:
#          0     1
# 0  824225  6268
# 1  161696  7811

# %% [markdown]
# ## Logistic - REF (Recursive Feature Elimination)

# %%
xtrain_dummy.shape
# Out:
# (1000000, 16883)

# %%
from sklearn.feature_selection import RFE

rfe = RFE(l, 3376)
rfe = rfe.fit(xtrain_dummy,ytrain)
print(rfe.support_)
print(rfe.ranking_)

# %%
@522 unique site id with only 1 record, 270 unique site id with only 2 record
print(train021.groupby('site_id').filter(lambda x: x['site_id'].count() ==1).site_id.unique())
print(train021.groupby('site_id').filter(lambda x: x['site_id'].count() ==2).site_id.unique())
# Out:
# ['02d41cd4' '33061721' '33fc9515' 'e22287e7' '558e8df6' '59073e64'
#  '70ce24b7' '4edf288e' 'caac8bbc' '47a12efe' '2ec90635' '8baeafec'
#  '9dae76b9' '3eb3e55c' '3a07270d' 'e515fa2b' '5f7d1de0' 'a4ae03ab'
#  '87ee32c4' '90c85c78' 'a8b000d7' '815c2cc6' 'fb021a56' '6594e957'
#  '0a65ddd5' 'ee95f85e' 'bf0ffd64' '1f2d9473' '79df8c62' 'c9ec94f6'
#  '1a3a5975' 'd3363614' '744b47d2' 'edc8c80d' '169cf8d6' '80c0bddc'
#  'b6fd3b03' 'd4db2fb0' '7f9a9620' '7c418d13' '8e07d653' 'a4dc6905'
#  '93f9c9e6' 'f5d1a67c' '2d7ea600' '3c04de20' '4ebbca24' '2cdfa4ac'
#  '2bd62959' '533eabb1' '2cf43c2d' 'bfec68aa' '3a3e276f' '6020550b'
#  '11508c8a' 'ee485e3f' '4f5494db' 'de44d8a8' '1b72ccd8' 'f203ec22'
#  '028f551e' '6b7ebaa0' '6cf6f576' '3c438678' '775f0108' 'b0f891da'
#  '303ba0ee' 'fe9c7f90' '5fa564da' 'c1e9bf32' '7d8f71db' 'cc26ad12'
#  '94db4ffc' '2d6a375a' 'debbc333' 'd3affde2' 'f9dc97a5' '66a4b77f'
#  '814b0498' '09ffd882' '508ea259' 'd77d8efd' '760bf05a' '70b78fa0'
# ...

# %%
@Stacked Bar to show distribution
for i in range(1,24):
    table = pd.crosstab(train021.iloc[:,i],train021.click)
    table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
